# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %%
df.shape
# Out:
# (101766, 50)

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
drop_cols = ['encounter_id', 'patient_nbr','weight','admission_type_id', 'discharge_disposition_id', 'admission_source_id','repaglinide', 'nateglinide', 'chlorpropamide','glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide','pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone','tolazamide', 'examide', 'citoglipton', 'insulin','glyburide-metformin', 'glipizide-metformin','glimepiride-pioglitazone', 'metformin-rosiglitazone','metformin-pioglitazone', 'change', 'diabetesMed','payer_code', 'medical_specialty','num_lab_procedures','num_procedures','max_glu_serum','diag_1','diag_2','diag_3','number_diagnoses','A1Cresult','metformin']

# %%
df.drop(drop_cols, inplace = True, axis=1)

# %%
df.shape
# Out:
# (101766, 9)

# %%
df.tail()
# Out:
#                    race  gender      age  time_in_hospital  num_medications  \
# 101761  AfricanAmerican    Male  [70-80)                 3               16
# 101762  AfricanAmerican  Female  [80-90)                 5               18
# 101763        Caucasian    Male  [70-80)                 1                9
# 101764        Caucasian  Female  [80-90)                10               21
# 101765        Caucasian    Male  [70-80)                 6                3
#
#         number_outpatient  number_emergency  number_inpatient readmitted
# 101761                  0                 0                 0        >30
# 101762                  0                 0                 1         NO
# 101763                  1                 0                 0         NO
# 101764                  0                 0                 1         NO
# 101765                  0                 0                 0         NO

# %%
df2=df[df['race'].isin(['AfricanAmerican','Caucasian']) & (df['gender'] =='Female') & (df['readmitted'] == '>30')]

# %%
df2['race'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='race'>

# %%
df2=df[df['race'].isin(['AfricanAmerican','Caucasian']) & (df['gender'] =='Male') & (df['readmitted'] == '>30')]

# %%
df2['race'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='race'>

# %%
pd.crosstab([df2['age'], df2['gender']], df2['race']).plot(kind='bar')
# Out:
# <Axes: xlabel='age,gender'>

# %%
pd.crosstab(df2['age'], df2['race']).plot(kind='bar')
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# I tried to show the readmission rates/ differences between caucasian males & females vs/ african american males & females. all of the graphs I pulled showed a higher rate of readmission after 30 days for caucasians but I believe this to be due to the vast different in the sample size of caucasian vs african american (more caucasians in general for the numbers are higher for them)
